# %%
import pandas as pd

# %%
chinese = pd.read_html("https://wayofasia.ru/articles/kitay/6-kitayskiy-yazyk/25-kitaiskie-imena.html")

# %%
chinese[1]
# Out:
#                        0            1          2  \
# 0   Русское произношение  По-китайски    Пиньинь
# 1                 Вэйдун           卫东    wèidōng
# 2                Вэньмин           文明    wénmíng
# 3                Вэньхуа           文华     wénhuá
# 4                Гуанмин           光明  guāngmíng
# 5                  Дэмин           德明     démíng
# 6                  Дэшэн           德胜    déshèng
# 7                Сунлинь           松林    sōnglín
# 8                 Сяолун           小龙   xiǎolóng
# 9                  Хэпин           和平     hépíng
# 10               Цзинсун           劲松   jìngsōng
# 11              Цзиньлун           金龙    jīnlóng
# 12              Цзяньпин           建平   jiànpíng
# 13                Чжиган           志刚    zhìgāng
# 14                Чжимин           志明    zhìmíng
# 15               Чжицзян           志强   zhìqiáng
# 16                 Шэнли           胜利    shènglì
# 17                 Юйлун           玉龙     yùlóng
# ...
